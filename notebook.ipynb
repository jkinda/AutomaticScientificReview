# %%
import os
import requests
import pandas as pd
import arxiv

def create_directory(topic):
    """
    Fonction pour créer un dossier basé sur le sujet de recherche.
    """
    # Remplacer les espaces par des underscores et enlever les caractères spéciaux
    directory_name = topic.replace(' ', '_').replace('/', '_')
    
    # Créer le dossier s'il n'existe pas déjà
    if not os.path.exists(directory_name):
        os.makedirs(directory_name)
    
    return directory_name

def search_arxiv(query, max_results=10):
    """
    Fonction pour rechercher des articles sur arXiv en fonction d'une requête.
    """
    search = arxiv.Search(
        query=query,
        max_results=max_results,
        sort_by=arxiv.SortCriterion.Relevance
    )
    return search.results()

def download_pdf(url, save_path):
    """
    Fonction pour télécharger le fichier PDF d'un article.
    """
    response = requests.get(url)
    with open(save_path, 'wb') as f:
        f.write(response.content)
    print(f'Téléchargé: {save_path}')

def scrape_and_download(query, max_articles=10):
    """
    Fonction principale pour scraper et télécharger les articles scientifiques.
    """
    # Créer un dossier spécifique au sujet
    folder_path = create_directory(query)
    
    results = search_arxiv(query, max_results=max_articles)
    
    articles = []

    for result in results:
        title = result.title
        authors = ', '.join([author.name for author in result.authors])
        summary = result.summary
        pdf_url = result.pdf_url
        publish_date = result.published.date()
        
        # Remplacer les caractères spéciaux dans le titre du fichier PDF
        pdf_filename = f"{title.replace(' ', '_').replace('/', '_')}.pdf"
        pdf_path = os.path.join(folder_path, pdf_filename)
        
        # Télécharger le PDF
        download_pdf(pdf_url, pdf_path)
        
        articles.append({
            'Title': title,
            'Authors': authors,
            'Summary': summary,
            'PDF_URL': pdf_url,
            'Publish Date': publish_date,
            'Downloaded PDF': pdf_path
        })

    # Convertir les résultats en DataFrame pour une analyse plus approfondie
    df = pd.DataFrame(articles)
    print(df)

# Exemple d'utilisation
scrape_and_download('Caractérisation des propiétés hydriques sols latéritiques utilisés en construction', max_articles=20)
# Out:
# /tmp/ipykernel_9188/3562661238.py:28: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   return search.results()
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Faisceaux_automorphes_pour_GL(n):_la_premiere_construction_de_Drinfeld.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Introduction_à_la_Physique_Quantique.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Segmentation_et_Interprétation_de_Nuages_de_Points_pour_la_Modélisation_d'Environnements_Urbains.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Perturbation_de_la_dynamique_de_difféomorphismes_en_topologie_C^1___Perturbation_of_the_dynamics_of_diffeomorphisms_in_the_C^1-topology.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Modules_projectifs_de_type_fini,_applications_linéaires_croisées_et_inverses_généralisés.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Géométrie_d'Arakelov_des_variétés_toriques_et_fibrés_en_droites_intégrables.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/La_correspondance_de_Langlands_locale_p-adique_pour_GL_2(Q_p).pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Sur_le_théorème_des_trois_distances_et_la_construction_des_gammes.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Compactification_minimale_et_mauvaise_reduction.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Caracterisation_Electromagnetique_in-Situ_De_Sols_En_Bande_L._Application_a_L'Identification_De_Profils_Geologiques.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Réduction_stable_en_dimension_supérieure_[d'après_Kollár,_Hacon-Xu...].pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Groupes_de_Selmer_et_accouplements.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Normalisation_de_la_langue_et_de_lecriture_arabe_:_enjeux_culturels_regionaux_et_mondiaux.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Champs_de_Hurwitz.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Aplicando_modelos_de_granos_de_polvo_con_propiedades_meteoriticas_al_continuo_ionizante_de_algunos_Nucleos_Activos_de_Galaxias.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Kinetic_inductance_detectors_for_millimeter_and_submillimeter_astronomy___Détecteurs_à_inductance_cinétique_pour_l'astronomie_millimétrique_et_sub-millimétrique.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/The_master_Painlevé_VI_heat_equation.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Presque_toute_surface_K3_contient_une_infinité_d'hypersurfaces_Levi-plates_linéaires.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Relations_dans_l'algèbre_de_Lie_fondamentale_des_motifs_elliptiques_mixtes.pdf
# Téléchargé: Caractérisation_des_propiétés_hydriques_sols_latéritiques_utilisés_en_construction/Agujeros_de_Gusano_en_Gravedad_(2+1).pdf
#                                                 Title  \
# 0   Faisceaux automorphes pour GL(n): la premiere ...
# 1                Introduction à la Physique Quantique
# 2   Segmentation et Interprétation de Nuages de Po...
# 3   Perturbation de la dynamique de difféomorphism...
# 4   Modules projectifs de type fini, applications ...
# 5   Géométrie d'Arakelov des variétés toriques et ...
# 6   La correspondance de Langlands locale p-adique...
# 7   Sur le théorème des trois distances et la cons...
# 8     Compactification minimale et mauvaise reduction
# 9   Caracterisation Electromagnetique in-Situ De S...
# 10  Réduction stable en dimension supérieure [d'ap...
# 11                 Groupes de Selmer et accouplements
# 12  Normalisation de la langue et de lecriture ara...
# 13                                  Champs de Hurwitz
# 14  Aplicando modelos de granos de polvo con propi...
# 15  Kinetic inductance detectors for millimeter an...
# 16               The master Painlevé VI heat equation
# 17  Presque toute surface K3 contient une infinité...
# 18  Relations dans l'algèbre de Lie fondamentale d...
# 19               Agujeros de Gusano en Gravedad (2+1)
#
#                                               Authors  \
# 0                                       Gerard Laumon
# 1                                    Constantin Piron
# 2                 Jorge Hernandez, Beatriz Marcotegui
# 3                                   Sylvain Crovisier
# 4   Gema M. Díaz--Toca, Laureano Gonzalez-Vega, He...
# 5                                          V. Maillot
# 6                                      Laurent Berger
# 7                                   Nicolas Trotignon
# 8                                        Benoit Stroh
# 9   François Demontoux, Gilles Ruffié, Daniel Medi...
# 10                                    Olivier Benoist
# 11                             Bernadette Perrin-Riou
# 12                 Henri Hudrisier, Ben Henda Mokhtar
# 13                              Antoine Chambert-Loir
# 14        Sinhue Amos Refugio Haro-Corzo, Luc Binette
# 15  Nicolas Boudou, Alain Benoit, Olivier Bourrion...
# 16                          Robert Conte, Ivan Dornic
# 17                                       Félix Lequen
# 18                      Samuel Baumard, Leila Schneps
# 19                                   Alexis Larranaga
#
#                                               Summary  \
# 0   Drinfeld a associe a tout systeme local irredu...
# 1   En nous laissant guider par la notion de champ...
# 2   Dans cet article, nous pr\'esentons une m\'eth...
# 3   Les travaux pr\'esent\'es dans ce m\'emoire po...
# 4   We give a general theory of generalised invers...
# 5   En nous appuyant sur une construction due \`a ...
# 6   La correspondance de Langlands locale p-adique...
# 7   We explain the link between the so-called "thr...
# 8   We construct the minimal compactification of s...
# 9   The development of instruments for remote sens...
# 10  The moduli space of stable curves of Deligne a...
# 11  Nekov\'a\v{r} vient de d\'emontrer que le rang...
# 12  Arabic language and writing are now facing a r...
# 13  On construit les champs de Hurwitz et on en do...
# 14  We construct extinction curves based on Mie's ...
# 15  We present recent developments in Kinetic Indu...
# 16  Given the second order scalar Lax pair of the ...
# 17  We investigate the construction of real analyt...
# 18  Hain and Matsumoto constructed a category of u...
# 19  Traversable wormholes are objects that present...
#
#                                     PDF_URL Publish Date  \
# 0   http://arxiv.org/pdf/alg-geom/9511004v1   1995-11-07
# 1    http://arxiv.org/pdf/physics/0204072v1   2002-04-24
# 2          http://arxiv.org/pdf/1306.3084v1   2013-06-13
# 3          http://arxiv.org/pdf/0912.2896v1   2009-12-15
# 4         http://arxiv.org/pdf/1809.08769v1   2018-09-24
# 5   http://arxiv.org/pdf/alg-geom/9706005v2   1997-06-16
# 6          http://arxiv.org/pdf/1002.4111v2   2010-02-22
# 7         http://arxiv.org/pdf/1505.05380v1   2015-05-18
# 8          http://arxiv.org/pdf/0811.1484v1   2008-11-10
# 9          http://arxiv.org/pdf/0906.4689v1   2009-06-25
# 10        http://arxiv.org/pdf/1904.03465v2   2019-04-06
# 11      http://arxiv.org/pdf/math/0211469v1   2002-11-14
# 12        http://arxiv.org/pdf/1703.04512v1   2017-02-24
# 13      http://arxiv.org/pdf/math/0210400v1   2002-10-25
# 14         http://arxiv.org/pdf/0802.2835v1   2008-02-20
# 15         http://arxiv.org/pdf/1201.5486v2   2012-01-26
# 16         http://arxiv.org/pdf/1409.1166v1   2014-09-03
# 17        http://arxiv.org/pdf/2109.08097v1   2021-09-16
# 18         http://arxiv.org/pdf/1310.5833v4   2013-10-22
# 19         http://arxiv.org/pdf/0706.1271v2   2007-06-08
#
#                                        Downloaded PDF
# 0   Caractérisation_des_propiétés_hydriques_sols_l...
# 1   Caractérisation_des_propiétés_hydriques_sols_l...
# 2   Caractérisation_des_propiétés_hydriques_sols_l...
# 3   Caractérisation_des_propiétés_hydriques_sols_l...
# 4   Caractérisation_des_propiétés_hydriques_sols_l...
# 5   Caractérisation_des_propiétés_hydriques_sols_l...
# 6   Caractérisation_des_propiétés_hydriques_sols_l...
# 7   Caractérisation_des_propiétés_hydriques_sols_l...
# 8   Caractérisation_des_propiétés_hydriques_sols_l...
# 9   Caractérisation_des_propiétés_hydriques_sols_l...
# 10  Caractérisation_des_propiétés_hydriques_sols_l...
# 11  Caractérisation_des_propiétés_hydriques_sols_l...
# 12  Caractérisation_des_propiétés_hydriques_sols_l...
# 13  Caractérisation_des_propiétés_hydriques_sols_l...
# 14  Caractérisation_des_propiétés_hydriques_sols_l...
# 15  Caractérisation_des_propiétés_hydriques_sols_l...
# 16  Caractérisation_des_propiétés_hydriques_sols_l...
# 17  Caractérisation_des_propiétés_hydriques_sols_l...
# 18  Caractérisation_des_propiétés_hydriques_sols_l...
# 19  Caractérisation_des_propiétés_hydriques_sols_l...

# %%
import os
import requests
import pandas as pd
import arxiv

def create_directory(topic):
    """
    Fonction pour créer un dossier basé sur le sujet de recherche.
    """
    # Remplacer les espaces par des underscores et enlever les caractères spéciaux
    directory_name = topic.replace(' ', '_').replace('/', '_')
    
    # Créer le dossier s'il n'existe pas déjà
    if not os.path.exists(directory_name):
        os.makedirs(directory_name)
    
    return directory_name

def generate_keywords(description):
    """
    Générer une liste de mots-clés pertinents à partir de la description.
    """
    # Diviser la description en mots, en enlevant les caractères spéciaux
    keywords = description.lower().split()
    keywords = [word.strip(",.!?()[]{}:;'\"") for word in keywords]
    return set(keywords)

def search_arxiv(query, max_results=10):
    """
    Fonction pour rechercher des articles sur arXiv en fonction d'une requête.
    """
    search = arxiv.Search(
        query=query,
        max_results=max_results,
        sort_by=arxiv.SortCriterion.Relevance
    )
    return search.results()

def filter_articles_by_keywords(articles, keywords, min_keywords=3):
    """
    Filtrer les articles en fonction de la présence d'un nombre minimum de mots-clés.
    """
    filtered_articles = []
    
    for article in articles:
        title = article.title.lower()
        summary = article.summary.lower()
        
        # Compter le nombre de mots-clés présents dans le titre ou le résumé
        keyword_count = sum(1 for keyword in keywords if keyword in title or keyword in summary)
        
        # Ajouter l'article à la liste filtrée s'il contient le nombre minimum de mots-clés
        if keyword_count >= min_keywords:
            filtered_articles.append(article)
    
    return filtered_articles

def download_pdf(url, save_path):
    """
    Fonction pour télécharger le fichier PDF d'un article.
    """
    response = requests.get(url)
    with open(save_path, 'wb') as f:
        f.write(response.content)
    print(f'Téléchargé: {save_path}')

def scrape_and_download(query, max_articles=10):
    """
    Fonction principale pour scraper et télécharger les articles scientifiques.
    """
    # Générer une liste de mots-clés à partir de la requête
    keywords = generate_keywords(query)
    print(f"Mots-clés générés: {keywords}")
    
    # Créer un dossier spécifique au sujet
    folder_path = create_directory(query)
    
    # Rechercher des articles sur arXiv en utilisant la requête de la description
    results = search_arxiv(query, max_results=max_articles)
    
    # Filtrer les articles en fonction des mots-clés
    filtered_results = filter_articles_by_keywords(results, keywords, min_keywords=3)
    
    articles = []

    for result in filtered_results:
        title = result.title
        authors = ', '.join([author.name for author in result.authors])
        summary = result.summary
        pdf_url = result.pdf_url
        publish_date = result.published.date()
        
        # Remplacer les caractères spéciaux dans le titre du fichier PDF
        pdf_filename = f"{title.replace(' ', '_').replace('/', '_')}.pdf"
        pdf_path = os.path.join(folder_path, pdf_filename)
        
        # Télécharger le PDF
        download_pdf(pdf_url, pdf_path)
        
        articles.append({
            'Title': title,
            'Authors': authors,
            'Summary': summary,
            'PDF_URL': pdf_url,
            'Publish Date': publish_date,
            'Downloaded PDF': pdf_path
        })

    # Convertir les résultats en DataFrame pour une analyse plus approfondie
    df = pd.DataFrame(articles)
    print(df)

# Exemple d'utilisation
scrape_and_download('Caractérisation des propriétés hydriques des sols latéritiques utilisés en construction', max_articles=20)
# Out:
# Mots-clés générés: {'sols', 'latéritiques', 'hydriques', 'des', 'utilisés', 'en', 'propriétés', 'caractérisation', 'construction'}
# /tmp/ipykernel_9188/282950441.py:37: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   return search.results()
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Faisceaux_automorphes_pour_GL(n):_la_premiere_construction_de_Drinfeld.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Introduction_à_la_Physique_Quantique.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/La_correspondance_de_Langlands_locale_p-adique_pour_GL_2(Q_p).pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Perturbation_de_la_dynamique_de_difféomorphismes_en_topologie_C^1___Perturbation_of_the_dynamics_of_diffeomorphisms_in_the_C^1-topology.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Sur_le_théorème_des_trois_distances_et_la_construction_des_gammes.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Géométrie_d'Arakelov_des_variétés_toriques_et_fibrés_en_droites_intégrables.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Réduction_stable_en_dimension_supérieure_[d'après_Kollár,_Hacon-Xu...].pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Les_surfaces_à_courbure_intégrale_bornée_au_sens_d'Alexandrov.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Groupes_de_Selmer_et_accouplements.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Normalisation_de_la_langue_et_de_lecriture_arabe_:_enjeux_culturels_regionaux_et_mondiaux.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/De_la_fixation_de_jauge_consideree_comme_un_des_beaux_arts_et_de_la_symetrie_de_Slavnov_qui_s'ensuit.pdf
# Téléchargé: Caractérisation_des_propriétés_hydriques_des_sols_latéritiques_utilisés_en_construction/Familles_de_polynomes_liees_aux_courbes_modulaires_X_1(l)_unicursales_et_points_rationnels_non-triviaux_de_courbes_elliptiques_quotient.pdf
#                                                 Title  \
# 0   Faisceaux automorphes pour GL(n): la premiere ...
# 1                Introduction à la Physique Quantique
# 2   La correspondance de Langlands locale p-adique...
# 3   Perturbation de la dynamique de difféomorphism...
# 4   Sur le théorème des trois distances et la cons...
# 5   Géométrie d'Arakelov des variétés toriques et ...
# 6   Réduction stable en dimension supérieure [d'ap...
# 7   Les surfaces à courbure intégrale bornée au se...
# 8                  Groupes de Selmer et accouplements
# 9   Normalisation de la langue et de lecriture ara...
# 10  De la fixation de jauge consideree comme un de...
# 11  Familles de polynomes liees aux courbes modula...
#
#                                               Authors  \
# 0                                       Gerard Laumon
# 1                                    Constantin Piron
# 2                                      Laurent Berger
# 3                                   Sylvain Crovisier
# 4                                   Nicolas Trotignon
# 5                                          V. Maillot
# 6                                     Olivier Benoist
# 7                                       Marc Troyanov
# 8                              Bernadette Perrin-Riou
# 9                  Henri Hudrisier, Ben Henda Mokhtar
# 10                                      Raymond Stora
# 11  Franck Leprevost, Michael E. Pohst, Andreas M....
#
#                                               Summary  \
# 0   Drinfeld a associe a tout systeme local irredu...
# 1   En nous laissant guider par la notion de champ...
# 2   La correspondance de Langlands locale p-adique...
# 3   Les travaux pr\'esent\'es dans ce m\'emoire po...
# 4   We explain the link between the so-called "thr...
# 5   En nous appuyant sur une construction due \`a ...
# 6   The moduli space of stable curves of Deligne a...
# 7   Dans les ann\'ees 1940-1970, Alexandrov et l'"...
# 8   Nekov\'a\v{r} vient de d\'emontrer que le rang...
# 9   Arabic language and writing are now facing a r...
# 10  La fixation de jauge est d\'efinie comme l'op\...
# 11  Soit l un entier et E_{c,l} la famille de Kube...
#
#                                     PDF_URL Publish Date  \
# 0   http://arxiv.org/pdf/alg-geom/9511004v1   1995-11-07
# 1    http://arxiv.org/pdf/physics/0204072v1   2002-04-24
# 2          http://arxiv.org/pdf/1002.4111v2   2010-02-22
# 3          http://arxiv.org/pdf/0912.2896v1   2009-12-15
# 4         http://arxiv.org/pdf/1505.05380v1   2015-05-18
# 5   http://arxiv.org/pdf/alg-geom/9706005v2   1997-06-16
# 6         http://arxiv.org/pdf/1904.03465v2   2019-04-06
# 7          http://arxiv.org/pdf/0906.3407v1   2009-06-18
# 8       http://arxiv.org/pdf/math/0211469v1   2002-11-14
# 9         http://arxiv.org/pdf/1703.04512v1   2017-02-24
# 10    http://arxiv.org/pdf/hep-th/9611115v1   1996-11-15
# 11      http://arxiv.org/pdf/math/0301370v1   2003-01-31
#
#                                        Downloaded PDF
# 0   Caractérisation_des_propriétés_hydriques_des_s...
# 1   Caractérisation_des_propriétés_hydriques_des_s...
# 2   Caractérisation_des_propriétés_hydriques_des_s...
# 3   Caractérisation_des_propriétés_hydriques_des_s...
# 4   Caractérisation_des_propriétés_hydriques_des_s...
# 5   Caractérisation_des_propriétés_hydriques_des_s...
# 6   Caractérisation_des_propriétés_hydriques_des_s...
# 7   Caractérisation_des_propriétés_hydriques_des_s...
# 8   Caractérisation_des_propriétés_hydriques_des_s...
# 9   Caractérisation_des_propriétés_hydriques_des_s...
# 10  Caractérisation_des_propriétés_hydriques_des_s...
# 11  Caractérisation_des_propriétés_hydriques_des_s...
